# %% [markdown]
# # BIG DATA MART SALES -PRACTICE PROJECT

# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('BIGDATATRAIN.csv')

# %%
test=pd.read_csv('BIGDATATEST.csv')

# %%
TRAIN=pd.DataFrame(train)

# %%
TEST=pd.DataFrame(test)

# %%
TRAIN
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# ## DULPICATE VALUES CHECK

# %%
df=TRAIN.drop_duplicates()

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# ### NO DUPLICATE VALUES

# %% [markdown]
# ## IDENTIFICATION OF VARIABLES & DATA TYPES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 865.6+ KB

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# ## WE HAVE INTEGARS, FLOAT AND CATAGORICAL DATA PRESENT, WE WILL CONVERT THE CATAGORICAL COLUMNS TO NUMERICAL ONES BY USING LABEL ENCODER

# %% [markdown]
# ## CHECKING THE UNIQUE VALUES IN  ALL COLUMNS

# %%
df['Item_Identifier'].unique()
# Out:
# array(['FDA15', 'DRC01', 'FDN15', ..., 'NCF55', 'NCW30', 'NCW05'],
#       dtype=object)

# %%
df['Item_Weight'].unique()
# Out:
# array([ 9.3  ,  5.92 , 17.5  , 19.2  ,  8.93 , 10.395, 13.65 ,    nan,
#        16.2  , 11.8  , 18.5  , 15.1  , 17.6  , 16.35 ,  9.   , 13.35 ,
#        18.85 , 14.6  , 13.85 , 13.   ,  7.645, 11.65 ,  5.925, 19.25 ,
#        18.6  , 18.7  , 17.85 , 10.   ,  8.85 ,  9.8  , 13.6  , 21.35 ,
#        12.15 ,  6.42 , 19.6  , 15.85 ,  7.39 , 10.195,  9.895, 10.895,
#         7.905,  9.195,  8.365,  7.97 , 17.7  , 19.35 ,  8.645, 15.6  ,
#        18.25 ,  7.855,  7.825,  8.39 , 12.85 , 19.   ,  5.905,  7.76 ,
#        16.75 , 15.5  ,  6.055,  6.305, 20.85 , 20.75 ,  8.895, 19.7  ,
#         8.75 , 13.3  ,  8.31 , 19.75 , 17.1  , 10.5  ,  6.635, 14.15 ,
#         8.89 ,  9.1  ,  7.5  , 16.85 ,  7.485, 11.6  , 12.65 , 20.25 ,
#         8.6  , 12.6  ,  8.88 , 20.5  , 13.5  ,  7.235,  6.92 ,  8.02 ,
#        12.8  , 16.6  , 14.   , 16.   , 21.25 ,  7.365, 18.35 ,  5.465,
#         7.27 ,  6.155, 19.5  , 15.2  , 14.5  , 13.1  , 12.3  , 11.1  ,
# ...

# %%
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
df['Item_Visibility'].unique()
# Out:
# array([0.0160473 , 0.01927822, 0.01676007, ..., 0.03518627, 0.14522065,
#        0.04487828])

# %%
df['Item_MRP'].unique()
# Out:
# array([249.8092,  48.2692, 141.618 , ...,  57.5904, 214.5218,  75.467 ])

# %%
df['Outlet_Identifier'].unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
df['Outlet_Establishment_Year'].unique()
# Out:
# array([1999, 2009, 1998, 1987, 1985, 2002, 2007, 1997, 2004], dtype=int64)

# %%
df['Outlet_Size'].unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
df['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
df['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
df['Item_Outlet_Sales'].unique()
# Out:
# array([3735.138 ,  443.4228, 2097.27  , ..., 7182.6504, 3608.636 ,
#        2778.3834])

# %%
df['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %% [markdown]
# ## CHECKING THE COUNT OF VARIOUS COLUMNS

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
df['Item_Visibility'].value_counts()
# Out:
# 0.000000    526
# 0.076975      3
# 0.162462      2
# 0.076841      2
# 0.073562      2
#            ...
# 0.013957      1
# 0.110460      1
# 0.124646      1
# 0.054142      1
# 0.044878      1
# Name: Item_Visibility, Length: 7880, dtype: int64

# %%
df['Item_MRP'].value_counts()
# Out:
# 172.0422    7
# 170.5422    6
# 196.5084    6
# 188.1872    6
# 142.0154    6
#            ..
# 97.3384     1
# 83.1934     1
# 96.6752     1
# 152.6682    1
# 75.4670     1
# Name: Item_MRP, Length: 5938, dtype: int64

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
df['Outlet_Establishment_Year'].value_counts()
# Out:
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df['Item_Outlet_Sales'].value_counts()
# Out:
# 958.7520     17
# 1342.2528    16
# 703.0848     15
# 1845.5976    15
# 1278.3360    14
#              ..
# 4124.6310     1
# 6622.7126     1
# 1614.5650     1
# 5602.7070     1
# 2778.3834     1
# Name: Item_Outlet_Sales, Length: 3493, dtype: int64

# %%
df['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
df['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
df['Item_Identifier'].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
df['Item_Weight'].value_counts()
# Out:
# 12.150    86
# 17.600    82
# 13.650    77
# 11.800    76
# 15.100    68
#           ..
# 7.275      2
# 7.685      1
# 9.420      1
# 6.520      1
# 5.400      1
# Name: Item_Weight, Length: 415, dtype: int64

# %%
df['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %% [markdown]
# ## CHECKING THE COUNT OF MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# ## SIMPLE IMPUTER- ITEM WEIGHT & OUTLET SIZE COLUMN TO FILL IN MISSING VALUES

# %%
from sklearn.impute import SimpleImputer

# %%
imp=SimpleImputer(missing_values=np.NaN,strategy='mean')

# %%
df['Item_Weight']=imp.fit_transform(df['Item_Weight'].values.reshape(-1,1))

# %%
imp1=SimpleImputer(missing_values=np.NaN,strategy='most_frequent')

# %%
df['Outlet_Size']=imp1.fit_transform(df['Outlet_Size'].values.reshape(-1,1))

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# ## NO NULL VALUES ARE PRESENT ANYMORE

# %% [markdown]
# ## FIRST 5 COLUMN CHECK

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ## LAST 5 COLUMN CHECK

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002      Medium               Tier 2
# ...

# %% [markdown]
# ## SAMPLE COLUMN CHECK

# %%
df.sample()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2879           DRA24    12.857645          Regular         0.069909
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 2879  Soft Drinks  163.2868            OUT019                       1985
#
#      Outlet_Size Outlet_Location_Type    Outlet_Type  Item_Outlet_Sales
# 2879       Small               Tier 1  Grocery Store           491.3604

# %% [markdown]
# ## CHECKING THE VAIROUS COLUMNS PRESENT IN THE DATA SET

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# # CREATING NEW ATTRIBUTES -FEATURE ENGINEERING

# %% [markdown]
# ## WE ARE REPLACING ITEM-IDENTIFIER & OUTLET ESTABLSIHMENT WITH THE FOLLOWING :

# %%
df['Item_Identifier']=df['Item_Identifier'].apply(lambda x: x[:2])

# %%
df['Outlet_Establishment_Year']=2013-df['Outlet_Establishment_Year']

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0                 FD        9.300          Low Fat         0.016047
# 1                 DR        5.920          Regular         0.019278
# 2                 FD       17.500          Low Fat         0.016760
# 3                 FD       19.200          Regular         0.000000
# 4                 NC        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518              FD        6.865          Low Fat         0.056783
# 8519              FD        8.380          Regular         0.046982
# 8520              NC       10.600          Low Fat         0.035186
# 8521              FD        7.210          Regular         0.145221
# 8522              DR       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# ## CHECKING THE UNIQUE & VALUE COUNTS OF ITEM IDENTIFIER COLUMNS

# %%
df['Item_Identifier'].unique()
# Out:
# array(['FD', 'DR', 'NC'], dtype=object)

# %%
df['Item_Identifier'].value_counts()
# Out:
# FD    6125
# NC    1599
# DR     799
# Name: Item_Identifier, dtype: int64

# %%
df['Outlet_Establishment_Year'].unique()
# Out:
# array([14,  4, 15, 26, 28, 11,  6, 16,  9], dtype=int64)

# %%
df['Outlet_Establishment_Year'].value_counts()
# Out:
# 28    1463
# 26     932
# 14     930
# 16     930
# 9      930
# 11     929
# 4      928
# 6      926
# 15     555
# Name: Outlet_Establishment_Year, dtype: int64

# %% [markdown]
# ## NON GRAPHICAL UNIVARIATE ANALYSIS

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                  15.168133
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                   4.000000
# 25%       9.310000         0.026989    93.826500                   9.000000
# 50%      12.857645         0.053931   143.012800                  14.000000
# 75%      16.000000         0.094585   185.643700                  26.000000
# max      21.350000         0.328391   266.888400                  28.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# ### OUTLIERS CHECK - HIGH DIFFERENCE BETWEEN 75TH PERCENTILE & MAX FIGURES IN ITEM_MRP & TARGET COLUMN WHICH STATES THAT THERE ARE OUTLEIRS PRESENT

# %% [markdown]
# ### SKEW CHECK SLIGHT DIFFERENCE IS PRESENT BETWEEN THE MEAN & MEDIAN OF ITEM_MR COLUMN AND MODRATE DIFFERENCE IS THERE IN OUTLET_SALES COLUMN WHICH RELECTS SKEWNESS

# %% [markdown]
# ## GRAPHICAL UNIVARIATE ANALYSIS

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df['Item_Identifier'].value_counts()
# Out:
# FD    6125
# NC    1599
# DR     799
# Name: Item_Identifier, dtype: int64

# %%
sns.countplot(df['Item_Identifier'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Identifier', ylabel='count'>

# %% [markdown]
# ### FD CATEGORY HAS THE HIGHEST NO OF PRODUCTS PRESENT ACCROSS STORES FOLLOWED BY NC AND DR

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
sns.countplot(df['Item_Fat_Content'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %% [markdown]
# ### LOW FAT ITEMS ARE MOST PRESENT IN STORE FOLLOWED BY REGULAR, THE QUANITY OF OTHER FAT PRODUCTS ARE VERY LESS

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
plt.figure(figsize=(12,12))
sns.countplot(df['Outlet_Identifier'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='count'>

# %% [markdown]
# ### OTHER THAN OUT010 AND OUT019, ALL THE OTHER OUTLETS ARE MORE THAN 800

# %%
df['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
plt.figure(figsize=(30,12))
sns.countplot(df['Item_Type'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Type', ylabel='count'>

# %% [markdown]
# ### FRUITS & VEGETABLES AND SNACK FOODS ARE HIGHLY PRESENT IN THE OUTLET FOLLOWED BY OTHER ITEMS

# %%
df['Outlet_Establishment_Year'].value_counts()
# Out:
# 28    1463
# 26     932
# 14     930
# 16     930
# 9      930
# 11     929
# 4      928
# 6      926
# 15     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
sns.countplot(df['Outlet_Establishment_Year'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='count'>

# %% [markdown]
# ### APPROXIMATELY 1400 OUTLETS ARE AS OLD AS 28 YEARS AND OTHERS RANGE BETWEEN 4-26 YEARS

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
sns.countplot(df['Outlet_Size'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Outlet_Size', ylabel='count'>

# %% [markdown]
# ### THE NUMBER OF MEDIUM SIZED OUTLETS ARE THE HIGHEST FOLLWED BY SMALL AND HIGH SIZE

# %%
df['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
sns.countplot(df['Outlet_Location_Type'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='count'>

# %% [markdown]
# ### TIER 3 HAS THE HIGHEST NUMBER OF OUTLETS PRESENT AS COMPARED TO TIER 2 AND TIER 1

# %%
df['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Outlet_Type'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Outlet_Type', ylabel='count'>

# %% [markdown]
# ### SUPER MARKET TYPE 1 OUTLETS ARE MAJORLY PRESENT FOLLOWED BY GROCERY STORE,SUPERMARKET TYPE 2 AND SUPERMARKET TYPE 3

# %%
sns.histplot(df['Item_Weight'],bins=25)
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Count'>

# %% [markdown]
# ### THE MAJORITY OF THE ITEMS WEIGH IN THE RANGE OF 12.5

# %%
sns.histplot(df['Item_MRP'],bins=25)
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Count'>

# %% [markdown]
# ### THE MAJORITY OF THE PRODUCTS COST BETWEEN 100-200 IN MRP

# %%
sns.histplot(df['Item_Visibility'],bins=25)
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Count'>

# %% [markdown]
# ### ABOUT 1200 PRODUCTS HAVE VISIBILITY IN THE RANGE OF 0.5

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
sns.scatterplot(x='Item_Identifier',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Identifier', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ### NC CATEOGORY OF FOOD HAS THE HIGHEST SALES ,FOLLOWED BY FD AND DR CATEGORIES

# %%
sns.scatterplot(x='Item_Weight',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ### PRODUCTS WHICH WEIGH IN THE RANGE OF 12.5 HAVE RECORDED THE HIGHEST SALES

# %%
sns.scatterplot(x='Item_Fat_Content',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ### LOW FAT PRODUCTS HAVE GENERATED THE HIGHEST SALES

# %%
sns.scatterplot(x='Item_Visibility',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ### SALES IS CONSISTENT BETWEEN 0-6000 WHEN THE VISIBILITY RANGES FROM 0 TO 0.18 AND THEN FALLS TO APP 500 ONLY

# %%
plt.figure(figsize=(20,20))
sns.scatterplot(x='Item_Type',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ### HOUSEHOLD GOODS HAVE RECORDED THE HIGHEST SALES

# %%
sns.scatterplot(x='Item_MRP',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ### AS THERES AN INCREASE IN MRP, THE TOTAL SALES ALSO INCREASES

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x='Outlet_Identifier',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ### OUTLET027 HAS RECORDED THE HIGHES SALES AS COMPARED TO OTHERS

# %%
sns.scatterplot(x='Outlet_Establishment_Year',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ### OUTLETS WHICH HAVE AGED ABOVE 25 YEARS HAVE THE HIGHEST SALES

# %%
sns.scatterplot(x='Outlet_Size',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ### MEDIUM SIZED OUTLETS HAVE RECORDED THE HIGHEST SALES FOLLOWED BY HIGH AND SMALL SIZED OUTLETS

# %%
sns.scatterplot(x='Outlet_Location_Type',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ### OUTLETS PRESENT IN TIER 3 HAVE RECORDED THE HIGHEST SALES

# %%
sns.scatterplot(x='Outlet_Type',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ### SALES CAPTURED BY SUPERMARKET TYPE 3 IS THE HIGHEST FOLLWED BY SUPER MARKET TYPE 1, TYPE 2 AND GROCERY STORE

# %%
sns.barplot(x='Item_Fat_Content',y='Item_MRP',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_MRP'>

# %% [markdown]
# ### ALL THE FAT CONTENT PRODUCTS MRP RANGES WITHIN 130 & 140

# %%
plt.figure(figsize=(20,15))
sns.barplot(x='Item_Type',y='Item_MRP',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_MRP'>

# %% [markdown]
# ### MRP OF ALL THE PRODUCTS ARE MOSTLY OVER 120

# %%
sns.scatterplot(x='Item_Visibility',y='Item_MRP',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Item_MRP'>

# %% [markdown]
# ### MRP IS AT THE HIGHEST WHEN VISIBILTY RANES BETWEEN 0 TO 0.15

# %%
sns.barplot(x='Outlet_Location_Type',y='Outlet_Establishment_Year',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='Outlet_Establishment_Year'>

# %% [markdown]
# ### OUTLETS PRESENT IN TIER 3 ARE SLIGHTLY OLDER AS COMPARED TO OUTLETS PRESENT IN TIER 1 AND TIER 2

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Outlet_Type',y='Outlet_Establishment_Year',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Outlet_Establishment_Year'>

# %% [markdown]
# ### SUPERMARKET TYPE 3 OUTLETS ARE THE OLDEST OF THE LOT FOLLWED BY GROCERY STORES

# %%
sns.barplot(x='Outlet_Size',y='Outlet_Establishment_Year',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Outlet_Establishment_Year'>

# %% [markdown]
# ### THE AGE OF HIGH OUTLET SIZES ARE MORE COMPARED TO SMALL & MEDIUM SIZED OUTLETS

# %% [markdown]
# ## MULTIVARIATE ANALYSIS

# %%
sns.catplot(x='Outlet_Location_Type',y='Item_Outlet_Sales',kind='box',data=df,hue='Outlet_Size')

# %% [markdown]
# ### TIER 1 AND TIER 2 HAVE SMALL AND MEDIUM SIZED STORES WHERE AS TIER 3 HAVE MEDIUM & HIGH SIZED STORES
# ### SALES FIGURES ACROSS ALL TIERS ARE MOSTLY SIMILAR

# %%
sns.catplot(x='Outlet_Location_Type',y='Item_Outlet_Sales',kind='box',data=df,hue='Outlet_Type')

# %% [markdown]
# ### TIER 3 HAS ALL 4 TYPES OF OUTLETS PRESENT WHERE SUPERMARKET TYPE 3 HAS RECORDED THE HIGHEST SALES

# %%
sns.catplot(x='Item_Identifier',y='Item_Outlet_Sales',kind='bar',data=df,hue='Outlet_Type')

# %% [markdown]
# ### SALES FIGURES OF FD IN SUPER MARKET 3 HAS GENERATED HIGHEST SALES ALL ACROSS

# %%
sns.catplot(x='Item_Identifier',y='Item_MRP',kind='bar',data=df,hue='Outlet_Type')

# %% [markdown]
# ### MRP OF ALL THREE TYPES OF PRODUCTS ARE SIMILAR IN NATURE, NO MAJOR DISCREPENCY FOUND IN ANY OUTLET TYPE

# %%
sns.catplot(x='Item_Identifier',y='Item_MRP',kind='bar',data=df,hue='Item_Fat_Content')

# %% [markdown]
# ### REG PRODUCT OF DR CATEGORY HAS RECORDED THE HIGHEST MRP

# %%
sns.catplot(x='Outlet_Size',y='Item_Outlet_Sales',kind='bar',data=df,hue='Outlet_Establishment_Year')

# %% [markdown]
# ### MEDIUM SIZED OUTLET AGED OVER 28 YEARS HAS RECORDED MAX SALES

# %%
sns.catplot(x='Outlet_Size',y='Item_Outlet_Sales',kind='bar',data=df,hue='Outlet_Location_Type')

# %% [markdown]
# ### MEDIUM SIZED OUTLETS HAVE PERFORMED SIMILARLY ACCORSS ALL 3 TIERS WHERE AS HIGHOUTLET SIZE HAS GENERATED MAX SALES IN TIER 3 AND SMALL SIZED OUTLET IN TIER 2 HAS RECORDED HIGHEST SALES ACCROSS ALL TIERS

# %% [markdown]
# ## ENCODING THE DATA SET

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Item_Fat_Content']=le.fit_transform(df['Item_Fat_Content'])

# %%
df['Item_Type']=le.fit_transform(df['Item_Type'])

# %%
df['Outlet_Size']=le.fit_transform(df['Outlet_Size'])

# %%
df['Outlet_Location_Type']=le.fit_transform(df['Outlet_Location_Type'])

# %%
df['Outlet_Type']=le.fit_transform(df['Outlet_Type'])

# %%
df['Outlet_Identifier']=le.fit_transform(df['Outlet_Identifier'])

# %%
df['Item_Identifier']=le.fit_transform(df['Item_Identifier'])

# %%
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   1        9.300                 1         0.016047
# 1                   0        5.920                 2         0.019278
# 2                   1       17.500                 1         0.016760
# 3                   1       19.200                 2         0.000000
# 4                   2        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518                1        6.865                 1         0.056783
# 8519                1        8.380                 2         0.046982
# 8520                2       10.600                 1         0.035186
# 8521                1        7.210                 2         0.145221
# 8522                0       14.800                 1         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %% [markdown]
# ## CORRELATION ANALYSIS

# %%
df.corr()
# Out:
#                            Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Identifier                   1.000000     0.063232         -0.140639
# Item_Weight                       0.063232     1.000000         -0.017331
# Item_Fat_Content                 -0.140639    -0.017331          1.000000
# Item_Visibility                  -0.037571    -0.012049          0.034042
# Item_Type                         0.007456     0.028015         -0.115958
# Item_MRP                          0.032517     0.024756         -0.000876
# Outlet_Identifier                -0.009730    -0.007975         -0.002357
# Outlet_Establishment_Year         0.008551     0.008301          0.000189
# Outlet_Size                      -0.000624    -0.007225         -0.012058
# Outlet_Location_Type              0.007661     0.004088         -0.004102
# Outlet_Type                       0.001136    -0.000566         -0.004214
# Item_Outlet_Sales                 0.011236     0.011550          0.009800
#
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### HIGH CORRELATION BETWEEN OUTLET IDENTIFIER & OUTLET LOCATION TYPE, MULTICOLINEARITY IS PRESENT IN THESE COLUMNS WHICH WE WILL TREAT LATER, REST ALL THE COLUMNS ARE SLIGHTLY OR MODERATELY CORRELATED WITH EACH OTHER

# %% [markdown]
# ## CORRELATION WRT TARGET COLUMN

# %%
df.corr()['Item_Outlet_Sales'].sort_values()
# Out:
# Item_Visibility             -0.128625
# Outlet_Size                 -0.086182
# Item_Fat_Content             0.009800
# Item_Identifier              0.011236
# Item_Weight                  0.011550
# Item_Type                    0.017048
# Outlet_Establishment_Year    0.049135
# Outlet_Location_Type         0.089367
# Outlet_Identifier            0.162325
# Outlet_Type                  0.401522
# Item_MRP                     0.567574
# Item_Outlet_Sales            1.000000
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# ### MRP & OUTLET TYPE HAVE A HIGH CORRELATION WRT THE TARGET COLUMN, WHERE AS THE OTHER PARAMTERS HAVE A MODERATE TO LOW POSITIVE & NEGATIVE CORRELATION

# %% [markdown]
# ## OUTLIERS CHECK - VISUAL

# %%
sns.boxplot(x=df['Item_Visibility'])
# Out:
# <AxesSubplot:xlabel='Item_Visibility'>

# %%
sns.boxplot(x=df['Outlet_Size'])
# Out:
# <AxesSubplot:xlabel='Outlet_Size'>

# %%
sns.boxplot(x=df['Item_Fat_Content'])
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content'>

# %%
sns.boxplot(x=df['Item_Identifier'])
# Out:
# <AxesSubplot:xlabel='Item_Identifier'>

# %%
sns.boxplot(x=df['Item_Weight'])
# Out:
# <AxesSubplot:xlabel='Item_Weight'>

# %%
sns.boxplot(x=df['Item_Type'])
# Out:
# <AxesSubplot:xlabel='Item_Type'>

# %%
sns.boxplot(x=df['Outlet_Establishment_Year'])
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year'>

# %%
sns.boxplot(x=df['Outlet_Location_Type'])
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type'>

# %%
sns.boxplot(x=df['Outlet_Identifier'])
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier'>

# %%
sns.boxplot(x=df['Outlet_Type'])
# Out:
# <AxesSubplot:xlabel='Outlet_Type'>

# %%
sns.boxplot(x=df['Item_MRP'])
# Out:
# <AxesSubplot:xlabel='Item_MRP'>

# %%
sns.boxplot(x=df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales'>

# %% [markdown]
# ### OUTLIERS ARE PRESENT IN THE FOLLOWING COLUMNS :
# #### ITEM OUTLET SALES
# #### OUTLET TYPE
# #### ITEM IDENTIFIER
# #### ITEM FAT CONTENT
# #### ITEM VISIBILITY

# %% [markdown]
# ## REMOVAL OF OUTLIERS

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
print(np.where(z>3))
# Out:
# (array([  49,   81,   83,  108,  130,  145,  151,  174,  199,  276,  304,
#         333,  339,  373,  396,  434,  456,  472,  489,  502,  521,  532,
#         615,  661,  694,  727,  753,  753,  809,  838,  854,  891,  935,
#         991,  997, 1009, 1010, 1034, 1090, 1124, 1133, 1138, 1159, 1183,
#        1209, 1254, 1272, 1291, 1311, 1324, 1372, 1433, 1434, 1450, 1496,
#        1501, 1506, 1512, 1542, 1549, 1560, 1575, 1576, 1615, 1617, 1644,
#        1651, 1684, 1723, 1753, 1769, 1805, 1827, 1841, 1859, 1998, 2062,
#        2088, 2109, 2111, 2122, 2143, 2168, 2173, 2216, 2223, 2238, 2251,
#        2293, 2324, 2331, 2438, 2439, 2445, 2516, 2535, 2552, 2569, 2586,
#        2613, 2660, 2678, 2728, 2776, 2855, 2895, 2905, 2971, 2973, 3011,
#        3017, 3083, 3087, 3098, 3154, 3206, 3225, 3234, 3241, 3242, 3243,
#        3286, 3335, 3367, 3399, 3407, 3458, 3474, 3480, 3488, 3491, 3497,
#        3509, 3540, 3545, 3582, 3602, 3667, 3709, 3720, 3750, 3757, 3767,
# ...

# %%
newdf=df[(z<3).all(axis=1)]

# %%
newdf
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   1        9.300                 1         0.016047
# 1                   0        5.920                 2         0.019278
# 2                   1       17.500                 1         0.016760
# 3                   1       19.200                 2         0.000000
# 4                   2        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518                1        6.865                 1         0.056783
# 8519                1        8.380                 2         0.046982
# 8520                2       10.600                 1         0.035186
# 8521                1        7.210                 2         0.145221
# 8522                0       14.800                 1         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
newdf.shape
# Out:
# (8222, 12)

# %% [markdown]
# ## DATA LOSS %

# %%
(8523-8222)/8523
# Out:
# 0.035316203214830456

# %% [markdown]
# ### THIS FALLS WITHIN THE ACCEPTABLE RANGE OF 10%, HENCE WE WILL PROCEED WITH THE NEW DATA SET

# %% [markdown]
# ## SKEW

# %%
newdf.plot(kind='density',subplots=True,figsize=(18,10),sharex=False,layout=(3,4))
plt.show()

# %% [markdown]
# ### SKEWNESS IS PRESENT IN SOME COLUMNS WHICH WE WILL TREAT LATER

# %%
newdf.skew()
# Out:
# Item_Identifier              0.104061
# Item_Weight                  0.087821
# Item_Fat_Content             0.291106
# Item_Visibility              0.794506
# Item_Type                    0.094578
# Item_MRP                     0.139153
# Outlet_Identifier           -0.067611
# Outlet_Establishment_Year    0.420927
# Outlet_Size                 -0.089519
# Outlet_Location_Type        -0.202794
# Outlet_Type                  0.957163
# Item_Outlet_Sales            0.877476
# dtype: float64

# %% [markdown]
# ### SKEWNESS IS PRESENT IN ITEM VISIBILITY (WHICH IS A CONTINUOUS) AND OUTLET TYPE WHICH IS ATEGORICAL IN NATURE, WE WILL REMOVE SKEWNESS BY POWER TRANSFORM IN CONTINUOUS COLUMS

# %% [markdown]
# ## SEPARATING X AND Y

# %%
x=newdf.iloc[:,0:11]

# %%
y=newdf.iloc[:,-1]

# %%
x
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   1        9.300                 1         0.016047
# 1                   0        5.920                 2         0.019278
# 2                   1       17.500                 1         0.016760
# 3                   1       19.200                 2         0.000000
# 4                   2        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518                1        6.865                 1         0.056783
# 8519                1        8.380                 2         0.046982
# 8520                2       10.600                 1         0.035186
# 8521                1        7.210                 2         0.145221
# 8522                0       14.800                 1         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8222, dtype: float64

# %% [markdown]
# ## MULTICOLINEARITY CHECK -VIF

# %%
from scipy import stats

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def cal_vif(x):
    vif=pd.DataFrame()
    vif['Variables']=x.columns
    vif['VIF_FACTOR']=[variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
    return(vif)

# %%
cal_vif(x)
# Out:
#                     Variables  VIF_FACTOR
# 0             Item_Identifier    5.099987
# 1                 Item_Weight    9.045637
# 2            Item_Fat_Content    5.945480
# 3             Item_Visibility    2.832078
# 4                   Item_Type    3.822367
# 5                    Item_MRP    5.795843
# 6           Outlet_Identifier   11.170356
# 7   Outlet_Establishment_Year    4.131872
# 8                 Outlet_Size    6.676357
# 9        Outlet_Location_Type   10.295672
# 10                Outlet_Type    7.744968

# %% [markdown]
# ### DROPPING OUTLET IDENTIFIER AS VIF SCORE IS HIGHER THAN THE ACCEPTABLE RANGE OF 10

# %%
x1=x.drop(['Outlet_Identifier'],axis=1)

# %% [markdown]
# ### CHECKING VIF SCORE AGAIN

# %%
def cal_vif(x1):
    vif=pd.DataFrame()
    vif['Variables']=x1.columns
    vif['VIF_FACTOR']=[variance_inflation_factor(x1.values,i)for i in range(x1.shape[1])]
    return(vif)

# %%
cal_vif(x1)
# Out:
#                    Variables  VIF_FACTOR
# 0            Item_Identifier    4.962050
# 1                Item_Weight    8.596573
# 2           Item_Fat_Content    5.634635
# 3            Item_Visibility    2.821863
# 4                  Item_Type    3.730414
# 5                   Item_MRP    5.625187
# 6  Outlet_Establishment_Year    4.098941
# 7                Outlet_Size    5.902638
# 8       Outlet_Location_Type    5.000678
# 9                Outlet_Type    4.518891

# %% [markdown]
# ### ALL THE COLUMNS ARE WITHIN THE RANGE OF 10, HENCE WE CAN CONCLUDE THAT THERE IS NO MULTICOLINEARITY PRESENT IN THE DATA SET

# %% [markdown]
# ## SKEWNESS CHECK- POWER TRANSFORM

# %%
from sklearn.preprocessing import power_transform

# %%
xnew=power_transform(x1)

# %%
a=pd.DataFrame(xnew, columns=x1.columns).skew().sort_values(ascending=True)

# %%
a
# Out:
# Outlet_Location_Type        -0.216697
# Item_Type                   -0.166116
# Item_MRP                    -0.112220
# Item_Weight                 -0.069934
# Outlet_Establishment_Year   -0.058029
# Outlet_Size                 -0.044624
# Outlet_Type                  0.010506
# Item_Fat_Content             0.017038
# Item_Identifier              0.044435
# Item_Visibility              0.116318
# dtype: float64

# %% [markdown]
# ### NO SKEWNESS IS PRESENT IN THE DATA

# %% [markdown]
# ## SCALING-

# %% [markdown]
# ### SINCE WE HAVE ALREADY USED POWER_TRANSFORM, OUR DATA HAS BEEN SCALED ALREADY , THERES NO NEED TO SCALE THE DATA SET AGAIN

# %% [markdown]
# ## XNEW & Y

# %%
xnew
# Out:
# array([[-0.17640715, -0.81766493, -0.55319135, ..., -0.28893369,
#         -1.37620889, -0.13508106],
#        [-2.10991444, -1.72429666,  1.1617017 , ..., -0.28893369,
#          1.0952949 ,  1.05485046],
#        [-0.17640715,  1.07935446, -0.55319135, ..., -0.28893369,
#         -1.37620889, -0.13508106],
#        ...,
#        [ 1.69854367, -0.49341756, -0.55319135, ...,  1.39061522,
#         -0.1266511 , -0.13508106],
#        [-0.17640715, -1.36561856,  1.1617017 , ..., -0.28893369,
#          1.0952949 ,  1.05485046],
#        [-2.10991444,  0.48880913, -0.55319135, ...,  1.39061522,
#         -1.37620889, -0.13508106]])

# %%
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8222, dtype: float64

# %%
y.shape
# Out:
# (8222,)

# %%
xnew.shape
# Out:
# (8222, 10)

# %% [markdown]
# ## MODEL TRAINING & TESTING

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,r2_score,mean_squared_error,mean_absolute_error
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## LINEAR REGRESSION

# %%
lr=LinearRegression()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(xnew,y,test_size=0.20,random_state=i)
    lr.fit(x_train,y_train)
    predr=lr.predict(x_train)
    pred=lr.predict(x_test)
    print('At random_state' ,{i}, 'the training accuracy test is', r2_score(y_train,predr))
    print('At random_state' ,{i}, 'the testing accuracy test is', r2_score(y_test,pred))
    print('\n')
# Out:
# At random_state {0} the training accuracy test is 0.5175802666516531
# At random_state {0} the testing accuracy test is 0.5151435741550812
#
#
# At random_state {1} the training accuracy test is 0.519041119727709
# At random_state {1} the testing accuracy test is 0.5086544356478222
#
#
# At random_state {2} the training accuracy test is 0.5161097965874364
# At random_state {2} the testing accuracy test is 0.5210624773358603
#
#
# At random_state {3} the training accuracy test is 0.5199108257822225
# At random_state {3} the testing accuracy test is 0.5061678896067253
#
#
# At random_state {4} the training accuracy test is 0.5120774138917836
# At random_state {4} the testing accuracy test is 0.5346299933664309
#
#
# At random_state {5} the training accuracy test is 0.5217001617870006
# At random_state {5} the testing accuracy test is 0.49790702483624294
#
#
# At random_state {6} the training accuracy test is 0.5075323931206956
# ...

# %% [markdown]
# ## AT RANDOM_STATE 6 WE HAVE ACHIEVED THE HIGHEST R2_SCORE OF 55.40%,HENCE WE WILL PROCEED WITH THAT

# %%
x_train,x_test,y_train,y_test=train_test_split(xnew,y,test_size=0.2,random_state=6)

# %%
LR=LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
PRELR=LR.predict(x_test)

# %%
print(r2_score(y_test,PRELR))
# Out:
# 0.5540436640860738

# %%
print(mean_squared_error(y_test,PRELR))
# Out:
# 1130371.8214661856

# %%
print(mean_absolute_error(y_test,PRELR))
# Out:
# 818.4665148269235

# %%
print('RMSE-',(sqrt(mean_squared_error(y_test,PRELR))))
# Out:
# RMSE- 1063.1894569954056

# %% [markdown]
# ## DECISION TREE REGRESSOR

# %%
dtc=DecisionTreeRegressor()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(xnew,y,test_size=0.20,random_state=i)
    dtc.fit(x_train,y_train)
    predtc=dtc.predict(x_train)
    predtc1=dtc.predict(x_test)
    print('At random_state' ,{i}, 'the training accuracy test is', r2_score(y_train,predtc))
    print('At random_state' ,{i}, 'the testing accuracy test is', r2_score(y_test,predtc1))
    print('\n')
# Out:
# At random_state {0} the training accuracy test is 1.0
# At random_state {0} the testing accuracy test is 0.2318142039848443
#
#
# At random_state {1} the training accuracy test is 1.0
# At random_state {1} the testing accuracy test is 0.15538197243935414
#
#
# At random_state {2} the training accuracy test is 1.0
# At random_state {2} the testing accuracy test is 0.15059247980871082
#
#
# At random_state {3} the training accuracy test is 1.0
# At random_state {3} the testing accuracy test is 0.15479252703458357
#
#
# At random_state {4} the training accuracy test is 1.0
# At random_state {4} the testing accuracy test is 0.241919069072294
#
#
# At random_state {5} the training accuracy test is 1.0
# At random_state {5} the testing accuracy test is 0.1719511270320203
#
#
# At random_state {6} the training accuracy test is 1.0
# At random_state {6} the testing accuracy test is 0.24560171701416977
#
#
# At random_state {7} the training accuracy test is 1.0
# ...

# %% [markdown]
# ## AT RANDOM_STATE 6 WE HAVE ACHIEVED THE HIGHEST R2_SCORE OF 24.56%,HENCE WE WILL PROCEED WITH THAT

# %%
DTC=DecisionTreeRegressor()

# %%
x_train,x_test,y_train,y_test=train_test_split(xnew,y,test_size=0.2,random_state=6)

# %%
DTC.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
PREDTC=DTC.predict(x_test)

# %%
print(r2_score(y_test,PREDTC))
# Out:
# 0.2519806014550934

# %%
print(mean_squared_error(y_test,PREDTC))
# Out:
# 1910226.6205719884

# %%
print(mean_absolute_error(y_test,PREDTC))
# Out:
# 971.4924573860183

# %%
print(sqrt(mean_squared_error(y_test,PREDTC)))
# Out:
# 1382.1094821221611

# %% [markdown]
# ## KNN REGRESSOR

# %%
knn=KNeighborsRegressor()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(xnew,y,test_size=0.20,random_state=i)
    knn.fit(x_train,y_train)
    preknn=knn.predict(x_train)
    preknn1=knn.predict(x_test)
    print('At random_state' ,{i}, 'the training accuracy test is', r2_score(y_train,preknn))
    print('At random_state' ,{i}, 'the testing accuracy test is', r2_score(y_test,preknn1))
    print('\n')
# Out:
# At random_state {0} the training accuracy test is 0.6689473815245688
# At random_state {0} the testing accuracy test is 0.49137226736166617
#
#
# At random_state {1} the training accuracy test is 0.6724990193650542
# At random_state {1} the testing accuracy test is 0.4639464901549514
#
#
# At random_state {2} the training accuracy test is 0.6681071857824584
# At random_state {2} the testing accuracy test is 0.496923729032113
#
#
# At random_state {3} the training accuracy test is 0.6705802285191274
# At random_state {3} the testing accuracy test is 0.49502570794800205
#
#
# At random_state {4} the training accuracy test is 0.6563258078718097
# At random_state {4} the testing accuracy test is 0.5180235655684103
#
#
# At random_state {5} the training accuracy test is 0.6622402107114653
# At random_state {5} the testing accuracy test is 0.4928984158585632
#
#
# At random_state {6} the training accuracy test is 0.6599210423640092
# ...

# %% [markdown]
# ## AT RANDOM_STATE 53 WE HAVE ACHIEVED THE HIGHEST R2_SCORE OF 53.90%,HENCE WE WILL PROCEED WITH THAT

# %%
KNN=KNeighborsRegressor()

# %%
x_train,x_test,y_train,y_test=train_test_split(xnew,y,test_size=0.2,random_state=53)

# %%
KNN.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
PREKNN=KNN.predict(x_test)

# %%
print(r2_score(y_test,PREKNN))
# Out:
# 0.4829454384474162

# %%
print(mean_squared_error(y_test,PREKNN))
# Out:
# 1304065.6512323872

# %%
print(mean_absolute_error(y_test,PREKNN))
# Out:
# 824.5239677568388

# %%
print(sqrt(mean_squared_error(y_test,PREKNN)))
# Out:
# 1141.9569393074273

# %% [markdown]
# ## RANDOM FOREST REGRESSOR

# %%
rm=RandomForestRegressor()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(xnew,y,test_size=0.20,random_state=i)
    rm.fit(x_train,y_train)
    prerm=rm.predict(x_train)
    prerm1=rm.predict(x_test)
    print('At random_state' ,{i}, 'the training accuracy test is', r2_score(y_train,prerm))
    print('At random_state' ,{i}, 'the testing accuracy test is', r2_score(y_test,prerm1))
    print('\n')
# Out:
# At random_state {0} the training accuracy test is 0.9363847062572547
# At random_state {0} the testing accuracy test is 0.5476954920319621
#
#
# At random_state {1} the training accuracy test is 0.9373527897990186
# At random_state {1} the testing accuracy test is 0.5320517175429493
#
#
# At random_state {2} the training accuracy test is 0.9350937417186121
# At random_state {2} the testing accuracy test is 0.5484356866424585
#
#
# At random_state {3} the training accuracy test is 0.9371335189906713
# At random_state {3} the testing accuracy test is 0.526610405474516
#
#
# At random_state {4} the training accuracy test is 0.9357919318409633
# At random_state {4} the testing accuracy test is 0.5783770554146133
#
#
# At random_state {5} the training accuracy test is 0.9370445987334425
# At random_state {5} the testing accuracy test is 0.5295143943397784
#
#
# At random_state {6} the training accuracy test is 0.9335055517693711
# ...

# %% [markdown]
# ## AT RANDOM_STATE 6 WE HAVE ACHIEVED THE HIGHEST R2_SCORE OF 60.39%,HENCE WE WILL PROCEED WITH THAT

# %%
x_train,x_test,y_train,y_test=train_test_split(xnew,y,test_size=0.2,random_state=6)

# %%
RM=RandomForestRegressor()

# %%
RM.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
PRERM=RM.predict(x_test)

# %%
print(r2_score(y_test,PRERM))
# Out:
# 0.6052036697056289

# %%
print(mean_squared_error(y_test,PRERM))
# Out:
# 1000695.8328520028

# %%
print(mean_absolute_error(y_test,PRERM))
# Out:
# 717.4029726832828

# %%
print(sqrt(mean_squared_error(y_test,PRERM)))
# Out:
# 1000.3478559241295

# %% [markdown]
# ## GRADIENT BOOST REGRESSOR

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
xg=GradientBoostingRegressor()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(xnew,y,test_size=0.20,random_state=i)
    xg.fit(x_train,y_train)
    prexg=xg.predict(x_train)
    prexg1=xg.predict(x_test)
    print('At random_state' ,{i}, 'the training accuracy test is', r2_score(y_train,prexg))
    print('At random_state' ,{i}, 'the testing accuracy test is', r2_score(y_test,prexg1))
    print('\n')
# Out:
# At random_state {0} the training accuracy test is 0.6202098471378966
# At random_state {0} the testing accuracy test is 0.5865174881888715
#
#
# At random_state {1} the training accuracy test is 0.6234216633384266
# At random_state {1} the testing accuracy test is 0.5772501805129098
#
#
# At random_state {2} the training accuracy test is 0.6197660876809095
# At random_state {2} the testing accuracy test is 0.5950900810652764
#
#
# At random_state {3} the training accuracy test is 0.6234605874127761
# At random_state {3} the testing accuracy test is 0.5755768030995659
#
#
# At random_state {4} the training accuracy test is 0.6135166209011627
# At random_state {4} the testing accuracy test is 0.6113025535473683
#
#
# At random_state {5} the training accuracy test is 0.6251940240348479
# At random_state {5} the testing accuracy test is 0.567587979346518
#
#
# At random_state {6} the training accuracy test is 0.6086462665659267
# ...

# %% [markdown]
# ## AT RANDOM_STATE 6 WE HAVE ACHIEVED THE HIGHEST R2_SCORE OF 63.45%,HENCE WE WILL PROCEED WITH THAT

# %%
XGB=GradientBoostingRegressor()

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y,test_size=0.2,random_state=6)

# %%
XGB.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
PREXGB=XGB.predict(x_test)

# %%
print(r2_score(y_test,PREXGB))
# Out:
# 0.635252482593399

# %%
print(mean_squared_error(y_test,PREXGB))
# Out:
# 924530.6825414108

# %%
print(mean_absolute_error(y_test,PREXGB))
# Out:
# 696.7573223280307

# %%
print(sqrt(mean_squared_error(y_test,PREXGB)))
# Out:
# 961.5251855991141

# %% [markdown]
# ## LASSO REGULARIZATION

# %%
from sklearn.linear_model import Lasso

# %%
ls=Lasso()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(xnew,y,test_size=0.20,random_state=i)
    ls.fit(x_train,y_train)
    prels=ls.predict(x_train)
    prels1=ls.predict(x_test)
    print('At random_state' ,{i}, 'the training accuracy test is', r2_score(y_train,prels))
    print('At random_state' ,{i}, 'the testing accuracy test is', r2_score(y_test,prels1))
    print('\n')
# Out:
# At random_state {0} the training accuracy test is 0.517575038411441
# At random_state {0} the testing accuracy test is 0.5151733045261595
#
#
# At random_state {1} the training accuracy test is 0.5190355169863942
# At random_state {1} the testing accuracy test is 0.5088080800507733
#
#
# At random_state {2} the training accuracy test is 0.5161040464752005
# At random_state {2} the testing accuracy test is 0.5210887045410368
#
#
# At random_state {3} the training accuracy test is 0.5199056086293463
# At random_state {3} the testing accuracy test is 0.5061571973308928
#
#
# At random_state {4} the training accuracy test is 0.5120716109569625
# At random_state {4} the testing accuracy test is 0.5345107553954411
#
#
# At random_state {5} the training accuracy test is 0.5216943138678424
# At random_state {5} the testing accuracy test is 0.49802893977547336
#
#
# At random_state {6} the training accuracy test is 0.5075266641037244
# ...

# %% [markdown]
# ## AT RANDOM_STATE 6 WE HAVE ACHIEVED THE HIGHEST R2_SCORE OF 55.40%,HENCE WE WILL PROCEED WITH THAT

# %%
x_train,x_test,y_train,y_test=train_test_split(xnew,y,test_size=0.2,random_state=6)

# %%
LS=Lasso()

# %%
LS.fit(x_train,y_train)
# Out:
# Lasso()

# %%
PRELS=LS.predict(x_test)

# %%
print(r2_score(y_test,PRELS))
# Out:
# 0.554044396646354

# %%
print(mean_squared_error(y_test,PRELS))
# Out:
# 1130369.9646352995

# %%
print(mean_squared_error(y_test,PRELS))
# Out:
# 1130369.9646352995

# %%
print(mean_absolute_error(y_test,PRELS))
# Out:
# 818.3728436136898

# %%
print(sqrt(mean_squared_error(y_test,PRELS)))
# Out:
# 1063.1885837589207

# %% [markdown]
# ## RIDGE REGULARIZATION

# %%
from sklearn.linear_model import Ridge

# %%
rd=Ridge()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(xnew,y,test_size=0.20,random_state=i)
    rd.fit(x_train,y_train)
    prerd=rd.predict(x_train)
    prerd1=rd.predict(x_test)
    print('At random_state' ,{i}, 'the training accuracy test is', r2_score(y_train,prerd))
    print('At random_state' ,{i}, 'the testing accuracy test is', r2_score(y_test,prerd1))
    print('\n')
# Out:
# At random_state {0} the training accuracy test is 0.5175802479367193
# At random_state {0} the testing accuracy test is 0.5151453045901626
#
#
# At random_state {1} the training accuracy test is 0.5190411009927933
# At random_state {1} the testing accuracy test is 0.508664874466067
#
#
# At random_state {2} the training accuracy test is 0.5161097782384898
# At random_state {2} the testing accuracy test is 0.5210630674335666
#
#
# At random_state {3} the training accuracy test is 0.5199108077405064
# At random_state {3} the testing accuracy test is 0.5061646669805483
#
#
# At random_state {4} the training accuracy test is 0.5120773959175287
# At random_state {4} the testing accuracy test is 0.5346180139087437
#
#
# At random_state {5} the training accuracy test is 0.521700143469096
# At random_state {5} the testing accuracy test is 0.49791279211286343
#
#
# At random_state {6} the training accuracy test is 0.5075323746291989
# ...

# %% [markdown]
# ## AT RANDOM_STATE 6 WE HAVE ACHIEVED THE HIGHEST R2_SCORE OF 55.40%,HENCE WE WILL PROCEED WITH THAT

# %%
RD=Ridge()

# %%
x_train,x_test,y_train,y_test=train_test_split(xnew,y,test_size=0.2,random_state=6)

# %%
RD=Ridge()

# %%
RD.fit(x_train,y_train)
# Out:
# Ridge()

# %%
PRERD=RD.predict(x_test)

# %%
print(r2_score(y_test,PRERD))
# Out:
# 0.5540397614504972

# %%
print(mean_squared_error(y_test,PRELS))
# Out:
# 1130369.9646352995

# %%
print(mean_absolute_error(y_test,PRERD))
# Out:
# 818.4621154212459

# %%
print(sqrt(mean_squared_error(y_test,PRELS)))
# Out:
# 1063.1885837589207

# %% [markdown]
# ### BOTH RIDGE AND LASSO HAVE GIVEN THE SAME ACCURACY OF 55.4% WHICH MATCHES THE ACCURACY OF LINEAR REGRESSION

# %% [markdown]
# ## CROSS VAL SCORE

# %%
for m in [LR,DTC,KNN,RM,XGB]:
    cv=cross_val_score(m,x1,y,cv=10)
    print('CV','is',(cv.mean()))
# Out:
# CV is 0.49406748175587023
# CV is 0.15443668731506102
# CV is 0.3953994095669834
# CV is 0.5386161338884579
# CV is 0.5839062531266466

# %%
### LR- 55.40%
### DTC -25.19
### KNN - 48.29
### RM -60.52%
### XGB-63.52%

# %% [markdown]
# ## CASES OF SLIGHT OVERFITTING IN ALL THE MODELS

# %%
(55.40-49.40)
# Out:
# 6.0

# %%
(25.19-15.44)
# Out:
# 9.750000000000002

# %%
(48.29-39.53)
# Out:
# 8.759999999999998

# %%
(60.52-53.86)
# Out:
# 6.660000000000004

# %%
(63.52-58.39)
# Out:
# 5.130000000000003

# %% [markdown]
# ## GRADIENT BOOSTING REGRESSOR HAS THE LEAST DIFFERENCE BETWEEN CROSS VAL MEAN SCORE(XGB) AND XGB MODEL AND HAS THE HIGHEST ACCURACY COMPARED TO OTHER MODELS , HENCE WE WILL HYPER THIS

# %% [markdown]
# ## GRID SEARCH OF GRADIENT BOOSTING REGRESSOR

# %%
XGB1=GradientBoostingRegressor()

# %%
dd1={'loss':['squared_error','absolute_error','huber','quantile'],'n_estimators':[50,100,150,200],'criterion':['friedman_mse','squared_error'],'min_samples_split':[2,3,4,5,6]}

# %%
gr=GridSearchCV(XGB1,dd1,cv=10)

# %%
gr.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error'],
#                          'loss': ['squared_error', 'absolute_error', 'huber',
#                                   'quantile'],
#                          'min_samples_split': [2, 3, 4, 5, 6],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
gr.best_params_
# Out:
# {'criterion': 'squared_error',
#  'loss': 'squared_error',
#  'min_samples_split': 6,
#  'n_estimators': 50}

# %%
XGB2=GradientBoostingRegressor(criterion='squared_error',loss='squared_error',min_samples_split=6,n_estimators=50)

# %%
XGB2.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(criterion='squared_error', min_samples_split=6,
#                           n_estimators=50)

# %%
PREXGB2=XGB2.predict(x_test)

# %%
print(r2_score(y_test,PREXGB2))
# Out:
# 0.6361903898212925

# %%
print(mean_absolute_error(y_test,PREXGB))
# Out:
# 696.7573223280307

# %%
print(mean_squared_error(y_test,PREXGB))
# Out:
# 924530.6825414108

# %% [markdown]
# ## THERE IS A SLIGHT IMPROVEMENT IN THE MODEL, THE SCORE HAS IMPROVED TO 63.61%

# %% [markdown]
# ## SAVING THE MODEL

# %%
import pickle

# %%
filename='churn.pkl'
pickle.dump(XGB2,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('churn.pkl','rb'))

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=['PREDICTED','ORIGINAL'])

# %%
conclusion
# Out:
#                  0            1           2            3            4     \
# PREDICTED  118.935298  1526.107777  717.742775  3577.989495  1185.714988
# ORIGINAL    77.232800   666.465800  245.680200  5273.136000  1406.169600
#
#                   5           6            7            8            9     \
# PREDICTED  3815.435915  3428.30876  1889.150995  2155.790694  2753.634164
# ORIGINAL   4554.072000  2175.16860  1488.728800   908.817000  1480.073400
#
#            ...         1635         1636         1637         1638  \
# PREDICTED  ...  1376.163583  3427.828703  2484.846191  1349.635078
# ORIGINAL   ...  1038.648000  2285.025600  3929.551600  1133.857400
#
#                   1639         1640         1641        1642         1643  \
# PREDICTED  1423.331816  2838.807596  3086.882796  887.326101  1889.150995
# ORIGINAL   1494.055200  4466.186400  3621.952000  848.895000  3206.492800
#
#                 1644
# PREDICTED  697.59402
# ORIGINAL   447.41760
#
# ...

# %% [markdown]
# ## TESTING THE TEST DATA SET

# %% [markdown]
# ## PREPROCESSING THE DATA SET IN THE SAME WAY WE PROCESSED THE EARLIER DATA SET

# %%
test=pd.read_csv('BIGDATATEST.csv')

# %%
TEST=pd.DataFrame(test)

# %% [markdown]
# ## DUPLICATE VALUES CHECK

# %%
TEST1=TEST.drop_duplicates()

# %%
TEST1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %% [markdown]
# ## NO DULPICATE VALUES, HENCE WE WILL PROCEED WITH TEST DATA SET

# %% [markdown]
# ## IDENTIFYING TYPES OF VARIABLES

# %%
TEST.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
TEST.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %% [markdown]
# ## UNIQUE VALUE CHECK AND COUNT CHECK OF THE VARIOUS COLUMNS

# %%
TEST['Item_Identifier'].unique()
# Out:
# array(['FDW58', 'FDW14', 'NCN55', ..., 'NCI29', 'FDP28', 'FDF04'],
#       dtype=object)

# %%
TEST['Item_Identifier'].value_counts()
# Out:
# DRF48    8
# FDZ50    8
# FDQ60    8
# FDN52    8
# FDW10    8
#         ..
# FDW49    1
# FDG38    1
# FDD38    1
# FDA15    1
# FDF04    1
# Name: Item_Identifier, Length: 1543, dtype: int64

# %%
TEST['Item_Weight'].unique()
# Out:
# array([20.75 ,  8.3  , 14.6  ,  7.315,    nan,  9.8  , 19.35 ,  6.305,
#         5.985, 16.6  ,  6.59 ,  4.785, 16.75 ,  6.135, 19.85 , 17.85 ,
#        13.6  ,  7.1  , 19.2  , 13.65 ,  6.785, 13.   ,  5.825, 13.8  ,
#        12.8  ,  9.5  , 12.5  ,  5.78 , 10.395, 18.35 , 21.1  , 19.75 ,
#         8.43 , 15.35 ,  6.71 , 10.195, 11.65 , 12.85 , 12.15 , 18.25 ,
#         5.98 , 12.65 , 13.1  , 20.7  ,  7.855, 13.35 , 17.25 ,  8.315,
#        21.35 ,  5.88 ,  7.435, 14.65 , 14.   , 18.2  , 17.6  ,  7.71 ,
#         7.81 , 16.35 , 16.1  ,  5.34 ,  5.51 ,  6.61 ,  6.38 ,  8.71 ,
#        17.75 ,  6.44 , 12.6  ,  7.935, 18.5  ,  6.035, 11.8  ,  6.26 ,
#        16.5  , 15.7  ,  6.635,  8.155,  6.175,  8.18 ,  8.355,  6.905,
#        20.35 , 19.25 ,  5.48 ,  5.425, 12.1  , 11.   ,  5.765,  5.44 ,
#         6.13 ,  8.195, 14.15 , 14.3  ,  5.635,  5.73 ,  7.155, 15.2  ,
#        15.25 ,  8.76 ,  9.13 , 19.6  , 10.   , 11.3  ,  6.57 , 13.15 ,
# ...

# %%
TEST['Item_Weight'].value_counts()
# Out:
# 10.500    57
# 17.600    53
# 15.600    48
# 20.250    47
# 19.350    46
#           ..
# 6.980      1
# 6.320      1
# 5.465      1
# 5.945      1
# 7.670      1
# Name: Item_Weight, Length: 410, dtype: int64

# %%
TEST['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'reg', 'Regular', 'LF', 'low fat'], dtype=object)

# %%
TEST['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: Item_Fat_Content, dtype: int64

# %%
TEST['Item_Visibility'].unique()
# Out:
# array([0.00756484, 0.03842768, 0.09957491, ..., 0.1429909 , 0.07352856,
#        0.10472015])

# %%
TEST['Item_Visibility'].value_counts()
# Out:
# 0.000000    353
# 0.060879      2
# 0.097213      2
# 0.058461      2
# 0.058132      2
#            ...
# 0.082382      1
# 0.026175      1
# 0.155144      1
# 0.069557      1
# 0.104720      1
# Name: Item_Visibility, Length: 5277, dtype: int64

# %%
TEST['Item_Type'].unique()
# Out:
# array([13,  4, 11,  6,  0,  8,  1,  7, 12, 14,  9,  5, 10,  3, 15,  2])

# %%
TEST['Item_Type'].value_counts()
# Out:
# Snack Foods              789
# Fruits and Vegetables    781
# Household                638
# Frozen Foods             570
# Dairy                    454
# Baking Goods             438
# Canned                   435
# Health and Hygiene       338
# Meat                     311
# Soft Drinks              281
# Breads                   165
# Hard Drinks              148
# Starchy Foods            121
# Others                   111
# Breakfast                 76
# Seafood                   25
# Name: Item_Type, dtype: int64

# %%
TEST['Item_MRP'].unique()
# Out:
# array([107.8622,  87.3198, 241.7538, ..., 141.3154, 214.6218,  79.796 ])

# %%
TEST['Item_MRP'].value_counts()
# Out:
# 57.0614     5
# 99.4700     4
# 141.2154    4
# 236.4564    4
# 186.8898    4
#            ..
# 156.3288    1
# 125.7388    1
# 42.6086     1
# 105.9964    1
# 79.7960     1
# Name: Item_MRP, Length: 4402, dtype: int64

# %%
TEST['Outlet_Identifier'].unique()
# Out:
# array([9, 2, 0, 5, 8, 3, 7, 4, 1, 6])

# %%
TEST['Outlet_Identifier'].value_counts()
# Out:
# OUT027    624
# OUT013    621
# OUT049    620
# OUT046    620
# OUT035    620
# OUT045    619
# OUT018    618
# OUT017    617
# OUT010    370
# OUT019    352
# Name: Outlet_Identifier, dtype: int64

# %%
TEST['Outlet_Establishment_Year'].unique()
# Out:
# array([1999, 2007, 1998, 1985, 1997, 2009, 2002, 1987, 2004], dtype=int64)

# %%
TEST['Outlet_Establishment_Year'].value_counts()
# Out:
# 1985    976
# 1987    621
# 1999    620
# 1997    620
# 2004    620
# 2002    619
# 2009    618
# 2007    617
# 1998    370
# Name: Outlet_Establishment_Year, dtype: int64

# %%
TEST['Outlet_Size'].unique()
# Out:
# array(['Medium', nan, 'Small', 'High'], dtype=object)

# %%
TEST['Outlet_Size'].value_counts()
# Out:
# Medium    1862
# Small     1592
# High       621
# Name: Outlet_Size, dtype: int64

# %%
TEST['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 1', 'Tier 2', 'Tier 3'], dtype=object)

# %%
TEST['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    2233
# Tier 2    1856
# Tier 1    1592
# Name: Outlet_Location_Type, dtype: int64

# %%
TEST['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Grocery Store', 'Supermarket Type3',
#        'Supermarket Type2'], dtype=object)

# %%
TEST['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    3717
# Grocery Store         722
# Supermarket Type3     624
# Supermarket Type2     618
# Name: Outlet_Type, dtype: int64

# %% [markdown]
# ## FEATURE ENGINEERING - TRANSFORMING THE ITEM_IDENTIFIER & OUTLET ESTABLSIHMENT YEAR

# %%
TEST['Item_Identifier']=TEST['Item_Identifier'].apply(lambda x: x[:2])

# %%
TEST['Outlet_Establishment_Year']=2013-TEST['Outlet_Establishment_Year']

# %%
TEST
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0                 FD       20.750          Low Fat         0.007565
# 1                 FD        8.300              reg         0.038428
# 2                 NC       14.600          Low Fat         0.099575
# 3                 FD        7.315          Low Fat         0.015388
# 4                 FD          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676              FD       10.500          Regular         0.013496
# 5677              FD        7.600          Regular         0.142991
# 5678              NC       10.000          Low Fat         0.073529
# 5679              FD       15.300          Regular         0.000000
# 5680              FD        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %% [markdown]
# # MISSING VALUES CHECK

# %%
TEST.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %% [markdown]
# ## IMPUTATION

# %%
TEST.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
imp=SimpleImputer(missing_values=np.NaN,strategy='mean')

# %%
TEST['Item_Weight']=imp.fit_transform(TEST['Item_Weight'].values.reshape(-1,1))

# %%
imp1=SimpleImputer(missing_values=np.NaN,strategy='most_frequent')

# %%
TEST['Outlet_Size']=imp1.fit_transform(TEST['Outlet_Size'].values.reshape(-1,1))

# %%
TEST.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %% [markdown]
# ### NO NULL VALUES EXIST ANYMORE IN THE DATA SET

# %% [markdown]
# ## FIRST 5 ROWS CHECK

# %%
TEST.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0              FD    20.750000          Low Fat         0.007565  Snack Foods
# 1              FD     8.300000              reg         0.038428        Dairy
# 2              NC    14.600000          Low Fat         0.099575       Others
# 3              FD     7.315000          Low Fat         0.015388  Snack Foods
# 4              FD    12.695633          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                         14      Medium
# 1   87.3198            OUT017                          6      Medium
# 2  241.7538            OUT010                         15      Medium
# 3  155.0340            OUT017                          6      Medium
# 4  234.2300            OUT027                         28      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %% [markdown]
# ## LAST 5 ROWS CHECK

# %%
TEST.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676              FD         10.5          Regular         0.013496
# 5677              FD          7.6          Regular         0.142991
# 5678              NC         10.0          Low Fat         0.073529
# 5679              FD         15.3          Regular         0.000000
# 5680              FD          9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5676                         16       Small               Tier 1
# 5677                          4      Medium               Tier 3
# ...

# %% [markdown]
# ## SAMPLE ROW CHECK

# %%
TEST.sample()
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 677              FD          9.8          Regular         0.045451
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 677  Baking Goods   36.2874            OUT018                          4
#
#     Outlet_Size Outlet_Location_Type        Outlet_Type
# 677      Medium               Tier 3  Supermarket Type2

# %% [markdown]
# ## NON GRAPHICAL UNIVARIATE ANALYSIS

# %%
TEST.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  5681.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                  15.171097
# std       4.245189         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                   4.000000
# 25%       9.195000         0.027047    94.412000                   9.000000
# 50%      12.695633         0.054154   141.415400                  14.000000
# 75%      15.850000         0.093463   186.026600                  26.000000
# max      21.350000         0.323637   266.588400                  28.000000

# %% [markdown]
# ### SKEWNESS CHECK - A DIFFERENCE BETWEEN MEAN AND MEDIAN IS HARDLY VISIBLE IN THE DATA SET, EXCEPT FOR A SLIGHT DIFFERENCE IN OUTLET IDENTIFIER

# %% [markdown]
# ### OUTLIERS CHECK-HIGH DIFFERENCE BETWEEN 75TH PERCENTILE & MAX FIGURES ARE IN ITEM MRP, AND SLIGHT DIFFERENCE IN ITEM VISIBILITY, ITEM WEIGHT AND ITEM TYPE

# %% [markdown]
# ## GRAPHICAL UNIVARIATE ANALYSIS

# %%
TEST['Item_Identifier'].value_counts()
# Out:
# FD    4076
# NC    1087
# DR     518
# Name: Item_Identifier, dtype: int64

# %%
sns.countplot(x=(TEST['Item_Identifier']))
# Out:
# <AxesSubplot:xlabel='Item_Identifier', ylabel='count'>

# %%
TEST['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: Item_Fat_Content, dtype: int64

# %%
sns.countplot(x=(TEST['Item_Fat_Content']))
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %%
TEST['Item_Type'].value_counts()
# Out:
# Snack Foods              789
# Fruits and Vegetables    781
# Household                638
# Frozen Foods             570
# Dairy                    454
# Baking Goods             438
# Canned                   435
# Health and Hygiene       338
# Meat                     311
# Soft Drinks              281
# Breads                   165
# Hard Drinks              148
# Starchy Foods            121
# Others                   111
# Breakfast                 76
# Seafood                   25
# Name: Item_Type, dtype: int64

# %%
sns.countplot(x=(TEST['Item_Type']))
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='count'>

# %%
TEST['Outlet_Identifier'].value_counts()
# Out:
# OUT027    624
# OUT013    621
# OUT049    620
# OUT046    620
# OUT035    620
# OUT045    619
# OUT018    618
# OUT017    617
# OUT010    370
# OUT019    352
# Name: Outlet_Identifier, dtype: int64

# %%
sns.countplot(x=(TEST['Outlet_Identifier']))
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='count'>

# %%
TEST['Outlet_Size'].value_counts()
# Out:
# Medium    3468
# Small     1592
# High       621
# Name: Outlet_Size, dtype: int64

# %%
sns.countplot(x=(TEST['Outlet_Size']))
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='count'>

# %%
TEST['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    2233
# Tier 2    1856
# Tier 1    1592
# Name: Outlet_Location_Type, dtype: int64

# %%
sns.countplot(x=(TEST['Outlet_Location_Type']))
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='count'>

# %%
TEST['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    3717
# Grocery Store         722
# Supermarket Type3     624
# Supermarket Type2     618
# Name: Outlet_Type, dtype: int64

# %%
sns.countplot(x=(TEST['Outlet_Type']))
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='count'>

# %%
TEST['Outlet_Establishment_Year'].value_counts()
# Out:
# 28    976
# 26    621
# 14    620
# 16    620
# 9     620
# 11    619
# 4     618
# 6     617
# 15    370
# Name: Outlet_Establishment_Year, dtype: int64

# %%
sns.countplot(x=(TEST['Outlet_Establishment_Year']))
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='count'>

# %%
sns.histplot(TEST['Item_MRP'],bins=25)
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Count'>

# %%
sns.histplot(TEST['Item_Visibility'],bins=25)
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Count'>

# %%
sns.histplot(TEST['Item_Weight'],bins=25)
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Count'>

# %% [markdown]
# ## GRAPHICAL BIVARIATE ANALYSIS

# %% [markdown]
# ## GRAPHICAL MULTIVARIATE UNIVARIATE ANALYSIS

# %% [markdown]
# ## LABEL ENCODER

# %%
TEST
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0                 FD    20.750000          Low Fat         0.007565
# 1                 FD     8.300000              reg         0.038428
# 2                 NC    14.600000          Low Fat         0.099575
# 3                 FD     7.315000          Low Fat         0.015388
# 4                 FD    12.695633          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676              FD    10.500000          Regular         0.013496
# 5677              FD     7.600000          Regular         0.142991
# 5678              NC    10.000000          Low Fat         0.073529
# 5679              FD    15.300000          Regular         0.000000
# 5680              FD     9.500000          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
TEST['Item_Identifier']=le.fit_transform(TEST['Item_Identifier'])

# %%
TEST['Item_Fat_Content']=le.fit_transform(TEST['Item_Fat_Content'])

# %%
TEST['Item_Type']=le.fit_transform(TEST['Item_Type'])

# %%
TEST['Outlet_Identifier']=le.fit_transform(TEST['Outlet_Identifier'])

# %%
TEST['Outlet_Size']=le.fit_transform(TEST['Outlet_Size'])

# %%
TEST['Outlet_Location_Type']=le.fit_transform(TEST['Outlet_Location_Type'])

# %%
TEST['Outlet_Type']=le.fit_transform(TEST['Outlet_Type'])

# %%
TEST
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   1    20.750000                 1         0.007565
# 1                   1     8.300000                 4         0.038428
# 2                   2    14.600000                 1         0.099575
# 3                   1     7.315000                 1         0.015388
# 4                   1    12.695633                 2         0.118599
# ...               ...          ...               ...              ...
# 5676                1    10.500000                 2         0.013496
# 5677                1     7.600000                 2         0.142991
# 5678                2    10.000000                 1         0.073529
# 5679                1    15.300000                 2         0.000000
# 5680                1     9.500000                 2         0.104720
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %% [markdown]
# ## CORRELATION

# %%
TEST.corr()
# Out:
#                            Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Identifier                   1.000000     0.062151         -0.150361
# Item_Weight                       0.062151     1.000000         -0.042625
# Item_Fat_Content                 -0.150361    -0.042625          1.000000
# Item_Visibility                  -0.067813    -0.016380          0.033591
# Item_Type                         0.018000     0.029657         -0.128945
# Item_MRP                          0.026742     0.045257         -0.014283
# Outlet_Identifier                 0.017324     0.020081         -0.000792
# Outlet_Establishment_Year        -0.007265    -0.013548          0.010088
# Outlet_Size                       0.006037     0.014735          0.000421
# Outlet_Location_Type             -0.017924    -0.011356         -0.000130
# Outlet_Type                      -0.006595     0.005080          0.000387
#
#                            Item_Visibility  Item_Type  Item_MRP  \
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(TEST.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### HIGH CORRELATION BETWEEN OUTLET IDENTIFIER & OUTLET LOCATION TYPE, MULTICOLINEARITY IS PRESENT IN THESE COLUMNS WHICH WE WILL TREAT LATER, REST ALL THE COLUMNS ARE SLIGHTLY OR MODERATELY CORRELATED WITH EACH OTHER

# %% [markdown]
# ## OUTLIERS- VISUAL

# %%
sns.boxplot(x=TEST['Item_Identifier'])
# Out:
# <AxesSubplot:xlabel='Item_Identifier'>

# %%
sns.boxplot(x=TEST['Item_Weight'])
# Out:
# <AxesSubplot:xlabel='Item_Weight'>

# %%
sns.boxplot(x=TEST['Item_Fat_Content'])
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content'>

# %%
sns.boxplot(x=TEST['Item_Visibility'])
# Out:
# <AxesSubplot:xlabel='Item_Visibility'>

# %%
sns.boxplot(x=TEST['Item_Type'])
# Out:
# <AxesSubplot:xlabel='Item_Type'>

# %%
sns.boxplot(x=TEST['Item_MRP'])
# Out:
# <AxesSubplot:xlabel='Item_MRP'>

# %%
sns.boxplot(x=TEST['Outlet_Identifier'])
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier'>

# %%
sns.boxplot(x=TEST['Outlet_Establishment_Year'])
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year'>

# %%
sns.boxplot(x=TEST['Outlet_Size'])
# Out:
# <AxesSubplot:xlabel='Outlet_Size'>

# %%
sns.boxplot(x=TEST['Outlet_Location_Type'])
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type'>

# %%
sns.boxplot(x=TEST['Outlet_Type'])
# Out:
# <AxesSubplot:xlabel='Outlet_Type'>

# %% [markdown]
# ### OUTLIERS ARE PRESENT IN THE FOLLOWING COLUMNS:
# #### OUTLET TYPE
# #### ITEM VISIBILTY
# #### ITEM FAT CONTENT
# #### ITEM IDENTIFIER

# %% [markdown]
# ## OUTLIERS REMOVAL

# %%
z1=np.abs(zscore(TEST))

# %%
z1
# Out:
#       Item_Identifier   Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0            0.191873  1.897460e+00          0.575284         1.134077
# 1            0.191873  1.035530e+00          4.104698         0.531850
# 2            1.723819  4.486336e-01          0.575284         0.661316
# 3            0.191873  1.267578e+00          0.575284         0.981416
# 4            0.191873  4.184768e-16          0.984710         1.032540
# ...               ...           ...               ...              ...
# 5676         0.191873  5.172506e-01          0.984710         1.018333
# 5677         0.191873  1.200437e+00          0.984710         1.508493
# 5678         1.723819  6.350414e-01          0.575284         0.153074
# 5679         0.191873  6.135406e-01          0.984710         1.281690
# 5680         0.191873  7.528321e-01          0.984710         0.761716
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
print(np.where(z1>3))
# Out:
# (array([   1,   46,   76,   78,   89,  103,  138,  242,  333,  369,  385,
#         474,  499,  543,  595,  637,  739,  783,  797,  815,  858,  871,
#         985,  996, 1025, 1037, 1046, 1105, 1143, 1191, 1256, 1256, 1270,
#        1284, 1314, 1321, 1411, 1422, 1437, 1516, 1539, 1547, 1577, 1616,
#        1710, 1757, 1780, 1812, 1823, 1853, 1857, 1915, 1919, 1927, 2019,
#        2070, 2167, 2179, 2230, 2271, 2275, 2365, 2365, 2380, 2393, 2504,
#        2516, 2561, 2595, 2605, 2609, 2625, 2628, 2677, 2779, 2798, 2836,
#        2843, 2866, 2915, 2926, 3039, 3077, 3097, 3267, 3294, 3313, 3316,
#        3346, 3357, 3362, 3378, 3461, 3502, 3565, 3622, 3638, 3679, 3744,
#        3778, 3783, 3950, 3970, 4021, 4052, 4133, 4146, 4147, 4148, 4159,
#        4208, 4232, 4255, 4328, 4330, 4334, 4340, 4352, 4365, 4421, 4478,
#        4542, 4575, 4616, 4616, 4689, 4692, 4726, 4801, 4804, 4845, 4846,
#        4870, 4919, 4921, 4941, 4965, 4970, 4976, 4999, 5121, 5132, 5154,
# ...

# %%
NEWTEST=TEST[(z1<3).all(axis=1)]

# %%
NEWTEST
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   1    20.750000                 1         0.007565
# 2                   2    14.600000                 1         0.099575
# 3                   1     7.315000                 1         0.015388
# 4                   1    12.695633                 2         0.118599
# 5                   1     9.800000                 2         0.063817
# ...               ...          ...               ...              ...
# 5676                1    10.500000                 2         0.013496
# 5677                1     7.600000                 2         0.142991
# 5678                2    10.000000                 1         0.073529
# 5679                1    15.300000                 2         0.000000
# 5680                1     9.500000                 2         0.104720
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
TEST.shape
# Out:
# (5681, 11)

# %%
NEWTEST.shape
# Out:
# (5525, 11)

# %% [markdown]
# ## DATA LOSS(%)

# %%
(5681-5525)/5681
# Out:
# 0.02745995423340961

# %% [markdown]
# ### THIS FALLS WITHIN OUR ACCEPTABLE RANGE OF 10%, HENCE WE WILL PROCED WITH NEWTEST DATA

# %% [markdown]
# ## SKEWNESS CHECK - VISUAL

# %%
NEWTEST.plot(kind='density',subplots=True,figsize=(18,10),sharex=False,layout=(3,4))
plt.show()

# %% [markdown]
# ### SKEWNESS IS PRESENT IN SOME COLUMNS, WHICH WE WILL TREAT

# %% [markdown]
# ## SKEWNESS CHECK -NUMERICAL

# %%
NEWTEST.skew()
# Out:
# Item_Identifier              0.113364
# Item_Weight                  0.139099
# Item_Fat_Content             0.275609
# Item_Visibility              0.786385
# Item_Type                    0.087677
# Item_MRP                     0.130290
# Outlet_Identifier           -0.069567
# Outlet_Establishment_Year    0.413720
# Outlet_Size                 -0.080824
# Outlet_Location_Type        -0.214502
# Outlet_Type                  0.949783
# dtype: float64

# %% [markdown]
# ### SKEWNESS IS PRESENT IN ITEM VISIBILITY (WHICH IS A CONTINUOUS) AND OUTLET TYPE WHICH IS ATEGORICAL IN NATURE, WE WILL REMOVE SKEWNESS BY POWER TRANSFORM IN CONTINUOUS COLUMS

# %% [markdown]
# ## VIF CHECK

# %%
cal_vif(NEWTEST)
# Out:
#                     Variables  VIF_FACTOR
# 0             Item_Identifier    5.135482
# 1                 Item_Weight    8.909170
# 2            Item_Fat_Content    6.005774
# 3             Item_Visibility    2.880998
# 4                   Item_Type    3.845543
# 5                    Item_MRP    5.884114
# 6           Outlet_Identifier   11.296310
# 7   Outlet_Establishment_Year    4.164095
# 8                 Outlet_Size    6.711746
# 9        Outlet_Location_Type   10.445117
# 10                Outlet_Type    7.800251

# %% [markdown]
# ### DROPPING OUTLET IDENTIFIER COLUMN AS THE VIF RANGE IS MORE THAN 10

# %%
NEWTEST1=NEWTEST.drop(['Outlet_Identifier'],axis=1)

# %%
cal_vif(NEWTEST1)
# Out:
#                    Variables  VIF_FACTOR
# 0            Item_Identifier    4.941070
# 1                Item_Weight    8.435169
# 2           Item_Fat_Content    5.653111
# 3            Item_Visibility    2.867647
# 4                  Item_Type    3.768547
# 5                   Item_MRP    5.760212
# 6  Outlet_Establishment_Year    4.128870
# 7                Outlet_Size    5.955278
# 8       Outlet_Location_Type    5.057032
# 9                Outlet_Type    4.593465

# %% [markdown]
# ### VIF IS WITHIN RANGE OF 10, HENCE WE CAN CONCLUDE THAT THERE IS NO MULTICOLINEARITY PRESENT IN THE DATA SET

# %%
XX=power_transform(NEWTEST1)

# %%
b=pd.DataFrame(XX,columns=NEWTEST1.columns).skew().sort_values(ascending=False)

# %%
b
# Out:
# Item_Visibility              0.105371
# Item_Identifier              0.045635
# Item_Fat_Content             0.015448
# Outlet_Type                  0.009486
# Outlet_Size                 -0.040808
# Outlet_Establishment_Year   -0.059117
# Item_Weight                 -0.062187
# Item_MRP                    -0.111874
# Item_Type                   -0.169372
# Outlet_Location_Type        -0.221369
# dtype: float64

# %% [markdown]
# ### OUR ACCEPTABLE RANGE FOR SKEWNESS IS +- 0.50 AND ALL THE DATA IS WITHIN THE SAID RANGE , HENCE WE CAN CONCLUDE THAT THERE IS NO SKEWNESS IN THE DATA AND BY USING POWER TRANSFORM , OUR DATA IS SCALED TOO

# %% [markdown]
# ## PREDICTING THE DATA SET (XX) WITH GRADIENT BOOSTING REGRESSOR

# %%
PRETEST=XGB2.predict(XX)

# %%
PRETEST
# Out:
# array([1673.28705874,  677.86605331, 2484.84619136, ..., 1856.94480026,
#        3511.31232826, 1346.72216628])

# %%
PREDICTED_SALES=pd.DataFrame(PRETEST)

# %%
PREDICTED_SALES
# Out:
#                 0
# 0     1673.287059
# 1      677.866053
# 2     2484.846191
# 3     4872.502968
# 4     1883.473305
# ...           ...
# 5520  2155.790694
# 5521  2568.815157
# 5522  1856.944800
# 5523  3511.312328
# 5524  1346.722166
#
# [5525 rows x 1 columns]

# %%
PREDICTED_SALES.to_csv('SALES_PREDICTION_BIGMART.csv')
